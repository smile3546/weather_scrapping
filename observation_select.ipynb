# %%
import pandas as pd

# %%
df = pd.read_csv('./csv/observation_stations.csv')
df.head()
# Out:
#        站號      站名     站種  海拔高度(m)          經度         緯度   城市              地址  \
# 0  466850  五分山雷達站  署屬有人站    756.0  121.781205  25.071182  新北市    瑞芳區靜安路四段1巷1號
# 1  466881      新北  署屬有人站     24.5  121.525196  24.959207  新北市       新店區莒光路29號
# 2  466900      淡水  署屬有人站     19.0  121.448906  25.164889  新北市    淡水區中正東路42巷6號
# 3  466910      鞍部  署屬有人站    837.6  121.529731  25.182586  臺北市  北投區陽明山竹子湖路111號
# 4  466920      臺北  署屬有人站      6.3  121.514853  25.037658  臺北市       中正區公園路64號
#
#        資料起始日期  撤站日期                                                 備註  \
# 0  1988-07-01   NaN                                        本站只有雷達觀測資料。
# 1  2023-01-01   NaN  為臺北氣象站板橋站區(站碼466880)遷移之新站，於2023/01/03上午11時取代舊站...
# 2  1942-10-01   NaN                                                NaN
# 3  1943-01-01   NaN                                                NaN
# 4  1896-08-11   NaN  1992/02至1997/08因本署改建，觀測地點移至臺北師院(466921)。2014至2...
#
#       原站號  新站號
# 0     NaN  NaN
# 1  466880  NaN
# 2     NaN  NaN
# ...
