# %% [markdown]
# 各山峰參考的自動氣象站
# ==

# %% [markdown]
# | 山名    | 最近氣象站 | 直線距離(km) |
# | ----- | ----- | -------- |
# | 奇萊主山  | 合歡山   | 3.92     |
# | 白姑大山  | 梨山    | 13.74    |
# | 北大武山  | 大漢山   | 24.02    |
# | 志佳陽大山 | 關山    | 147.46   |
# | 羊頭山   | 小奇萊   | 21.58    |
# | 畢祿山   | 雪山東峰  | 22.87    |
# | 西巒大山  | 西巒    | 0.22     |
# | 雪山東峰  | 雪山東峰  | 0.79     |
# | 塔關山   | 澤子    | 33.72    |
# | 關山嶺山  | 清水林道  | 1.97     |
# | 屏風山   | 萬大林道  | 3.82     |
# | 品田山   | 雪山東峰  | 0.41     |
# | 池有山   | 雪山東峰  | 2.40     |
# | 小關山   | 小關山   | 0.21     |
# | 郡大山   | 雪山東峰    | 7.22    |
# ||藤枝	|	|19.06|
# ||      大漢山  |                    |  |70.6|
# | 玉山前峰  | 玉山    | 1.51     |
# | 玉山主峰  | 玉山風口  | 0.18     |

# %% [markdown]
# 奇萊
# ---

# %% [markdown]
# 站碼：C0I530
# 站名：小奇萊
# 高度：3014
# WGS84十分位經度座標：121.2957
# WGS84十分位緯度座標：24.1318

# %% [markdown]
# 站碼：C0I540
# 站名：奇萊稜線
# 高度：3344
# WGS84十分位經度座標：121.3265
# WGS84十分位緯度座標：24.1092

# %% [markdown]
# 合歡山
# ---

# %% [markdown]
# 站碼：C0H9C0
# 站名：合歡山
# 高度：3402
# WGS84十分位經度座標：121.2725
# WGS84十分位緯度座標：24.1434

# %% [markdown]
# 白姑大山
# ---

# %% [markdown]
# 站碼：C2F860
# 站名：梨山
# 高度：2215
# WGS84十分位經度座標：121.2437
# WGS84十分位緯度座標：24.2475

# %% [markdown]
# 北大武
# ---

# %% [markdown]
# 站碼：C0F0E0
# 站名：南湖圈谷
# 高度：3557
# WGS84十分位經度座標：121.4447
# WGS84十分位緯度座標：24.3637
#
# 站碼：C0H9C0
# 站名：合歡山
# 高度：3402
# WGS84十分位經度座標：121.2725
# WGS84十分位緯度座標：24.1434

# %% [markdown]
# 志佳陽大山
# ---

# %% [markdown]
# 站碼：C0S890
# 站名：關山
# 高度：238
# WGS84十分位經度座標：121.1750
# WGS84十分位緯度座標：23.0395

# %% [markdown]
# 羊頭山
# ---

# %% [markdown]
# 站碼：C0I530
# 站名：小奇萊
# 高度：3014
# WGS84十分位經度座標：121.2957
# WGS84十分位緯度座標：24.1318
#
# 距離較近的丹大沒辦法用 雖然驗收了但還沒啟用
# 備註：自2006年起，設備不再維護，暫時停止觀測。本站於2015/3/28起進行儀器汰換，並於2015/7/1完成驗收。

# %% [markdown]
# 畢祿山
# ---

# %% [markdown]
# 西巒大山
# ---

# %% [markdown]
# 站碼：C1I310
# 站名：西巒
# 高度：1033
# WGS84十分位經度座標：120.8840
# WGS84十分位緯度座標：23.7545
# 只是雨量站 可憐

# %% [markdown]
# 雪山東峰
# ---

# %% [markdown]
# 站碼：C0F9Z0
# 站名：雪山東峰
# 高度：3193
# WGS84十分位經度座標：121.2687
# WGS84十分位緯度座標：24.3888

# %% [markdown]
# 塔關山
# ---

# %% [markdown]
# 上谷關沒資料
#
# 站碼：C0F9O0
# 站名：潭子
# 高度：175
# WGS84十分位經度座標：120.7039
# WGS84十分位緯度座標：24.2131
# 高度太低

# %% [markdown]
# 關山嶺山
# ---

# %% [markdown]
# 站碼：C0Z320
# 站名：清水林道
# 高度：646
# WGS84十分位經度座標：121.1883
# WGS84十分位緯度座標：23.2712

# %% [markdown]
# 屏風山
# ---

# %% [markdown]
# 站碼：C0I490
# 站名：萬大林道
# 高度：1601
# WGS84十分位經度座標：121.0914
# WGS84十分位緯度座標：23.9282

# %% [markdown]
# 品田山 池有山
# ---

# %% [markdown]
# 站碼：C0F9Z0
# 站名：雪山東峰
# 高度：3193
# WGS84十分位經度座標：121.2687
# WGS84十分位緯度座標：24.3888

# %% [markdown]
# 小關山
# ---

# %% [markdown]
# 站碼：C1V220
# 站名：小關山
# 高度：1781
# WGS84十分位經度座標：120.8136
# WGS84十分位緯度座標：23.1542
# 只有雨量站

# %% [markdown]
# 郡大山
# ---

# %% [markdown]
# 站碼：C0R440
# 站名：大漢山
# 高度：1654
# WGS84十分位經度座標：120.7532
# WGS84十分位緯度座標：22.4053

# %% [markdown]
# 玉山前峰
# ---

# %% [markdown]
# 站碼：467550
# 站名：玉山
# 高度：3844.8
# WGS84十分位經度座標：120.9594
# WGS84十分位緯度座標：23.4872
#
# 站碼：C0I520
# 站名：玉山風口
# 高度：3860
# WGS84十分位經度座標：120.9560
# WGS84十分位緯度座標：23.4705

# %% [markdown]
# 玉山主峰單攻
# ---

# %% [markdown]
# 站碼：467550
# 站名：玉山
# 高度：3844.8
# WGS84十分位經度座標：120.9594
# WGS84十分位緯度座標：23.4872
#
# 站碼：C0I520
# 站名：玉山風口
# 高度：3860
# WGS84十分位經度座標：120.9560
# WGS84十分位緯度座標：23.4705

# %% [markdown]
# 嘉明湖
# ---
